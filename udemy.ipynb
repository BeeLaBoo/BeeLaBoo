# %% [markdown]
# <a href="https://www.kaggle.com/beelaboo/udemy?scriptVersionId=90371802" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/udemy-courses/udemy_courses.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('../input/udemy-courses/udemy_courses.csv')

# %%
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# 4 major subjects

# %%
## which subject has max nuembers of courses

# %%
data['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
## Free course

data[data['price']== 0]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
data[data['is_paid'] == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %%
## best selling

data.sort_values('num_subscribers' ,ascending = False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1569     726314       Create Beautiful Image Maps for Your Website
# 1473     185526                             MicroStation - Células
# 1472     181268               Photoshop: Creando elemental de aire
# 1471     188584                        Letras en Adobe Illustrator
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %% [markdown]
# Learn HTML5 Programming From Scratch

# %%
##the worst selling
data.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  \
# 885     1032648                               beginning accounting
# 456     1247992  Introduction to Project Management for Finance...
# 457     1251582              Best Practices in Corporate Budgeting
# 458     1258666                Financial Statement Auditing Cycles
# 459     1168172       Case studies on credit appraisal for bankers
# ...         ...                                                ...
# 3232     764164              The Complete Web Developer Course 2.0
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3230     625204                         The Web Developer Bootcamp
# 3032      59014                     Coding for Entrepreneurs Basic
# 2827      41295               Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 885         https://www.udemy.com/beginning_accounting/     True     20
# ...

# %%
## Python and price < 100

data[data['course_title'].str.contains('Python') & (data['price'] <100 )]
# Out:
#       course_id                                       course_title  \
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2960     270808                      Projects in Django and Python
# 3133     574082        Web Scraping with Python, Ruby & import. io
# 3194    1063722            Learn Python Django - A Hands-On Course
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 3333    1038538            Introduction to QGIS Python Programming
# ...

# %%
len(data[data['course_title'].str.contains('Python') & (data['price'] <100 )])
# Out:
# 14

# %%
data[data['course_title'].str.contains('Graphic design') & (data['price'] <100 )]
# Out:
#       course_id                      course_title  \
# 1305     286508  Graphic design - The Quick Guide
#
#                                                     url  is_paid  price  \
# 1305  https://www.udemy.com/graphic-design-the-quick...     True     30
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 1305             1350           29            11  Beginner Level
#
#       content_duration   published_timestamp         subject
# 1305          0.633333  2014-08-29T08:03:27Z  Graphic Design

# %%
data.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %% [markdown]
# it is datetime format already

# %%
## courses launched in 2015
## convert to datetime
## extract year of publishing

data['published_timestamp'] = pd.to_datetime(data['published_timestamp'])  ## no need because datetime format already

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance
# 1 2017-03-09 16:34:20+00:00  Business Finance

# %%
data['year'] = data['published_timestamp'].dt.year

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
data[data['year'] == 2015]
# Out:
#       course_id                                       course_title  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 17       564966  The Complete Chart Pattern Trading Course: A P...
# ...         ...                                                ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3669     679992                  Building Better APIs with GraphQL
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3675     635248                      Learn and Build using Polymer
#
#                                                     url  is_paid  price  \
# 7     https://www.udemy.com/trading-chart-patterns-f...     True     95
# ...

# %%
len(data[data['year'] == 2015])
# Out:
# 1014

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %% [markdown]
# 4 levels

# %%
## by level , how many courses for each skill level

data.groupby('level')['course_title'].count()
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Expert Level            58
# Intermediate Level     421
# Name: course_title, dtype: int64

# %%
data['course_title'].count()

##total corses
# Out:
# 3678

# %%
data.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.num_subscribers.sum()
# Out:
# 11759120
